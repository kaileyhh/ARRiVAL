# %% [markdown]
# ### Compute louvain

# %%
# import statements

from IPython.display import SVG
import networkx as nx
import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pickle
from math import comb
import statistics
from community import community_louvain

# %%
ibs = "ibs"
ibd = "ibd"
crc = "crc"
classifier = 'family'

ibs_files = glob.glob('../results/'+ibs+'/'+ibs+'_dicts/*')
ibd_files = glob.glob('../results/'+ibd+'/'+ibd+'_dicts/*')
crc_files = glob.glob('../results/'+ibs+'/'+ibs+'_dicts/*')

ibs_graph = pickle.load(open("../results/graphs/ibs_graph.pkl", "rb"))
ibd_graph = pickle.load(open("../results/graphs/ibd_graph.pkl", "rb"))
crc_graph = pickle.load(open("../results/graphs/crc_graph.pkl", "rb"))

# %%
# ibs

partition = community_louvain.best_partition(ibs_graph)
plt.figure(figsize=(15,15), dpi = 600)

pos = nx.spring_layout(ibs_graph)
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(ibs_graph, pos, partition.keys(), node_size = 20, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(ibs_graph, pos, alpha=0.5)

for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    
plt.show()
# Out:
# /var/folders/4w/pfmmd55j7fb9v5sf2d7_759m0000gn/T/ipykernel_39509/612763587.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', max(partition.values()) + 1)

# %%
# ibd
# ibd_graph.remove_nodes_from(list(nx.isolates(crc_graph)))
partition = community_louvain.best_partition(ibd_graph)
plt.figure(figsize=(15,15), dpi = 600)

pos = nx.spring_layout(ibd_graph)
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(ibd_graph, pos, partition.keys(), node_size = 20, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(ibd_graph, pos, alpha=0.5)

for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    
plt.show()
# Out:
# /var/folders/4w/pfmmd55j7fb9v5sf2d7_759m0000gn/T/ipykernel_39509/2298013412.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', max(partition.values()) + 1)

# %%
# crc
partition = community_louvain.best_partition(crc_graph)
plt.figure(figsize=(15,15), dpi = 600)

pos = nx.spring_layout(crc_graph)
cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
nx.draw_networkx_nodes(crc_graph, pos, partition.keys(), node_size = 20, cmap=cmap, node_color=list(partition.values()))
nx.draw_networkx_edges(crc_graph, pos, alpha=0.5)

for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    
plt.show()
# Out:
# /var/folders/4w/pfmmd55j7fb9v5sf2d7_759m0000gn/T/ipykernel_39509/2088120025.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
