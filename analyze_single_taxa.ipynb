# %% [markdown]
# Read in data from classification files produced by the bash script `classifier_script.sh` and output a list of taxa.

# %%
# import statements, setup
import csv
import pickle
import glob
import os

to_classify = ["sample", "domain", "phylum", "class", "order", "family", "genus"]
files = glob.glob("/Users/maxinelui/Documents/CMU Spring 2024/Comp Bio/Group_Project/RDPTools_data/OutputDir/*")

# %%
# parse RDP result

for filename in files:
    # print(filename)
    classified = open(filename, "r")
    
    filename_short = os.path.basename(filename)[:-15]
    print(filename_short)

    lines = classified.readlines()


    taxa_dict = {}
    for item in to_classify:
        taxa_dict[item] = {}

    # write classifier to csv, save dictionary
    for line in lines:
        split = line.split()
        write = [split[0]]
        for i in range(len(split)):
            if split[i] in to_classify:
                write.append(split[i-1])
                if split[i-1] not in taxa_dict[split[i]]:
                    taxa_dict[split[i]][split[i-1]] = 1
                else:
                    taxa_dict[split[i]][split[i-1]] += 1

    classified.close()

    # save dictionary to file

    with open('results/ibd/ibd_dicts/' + filename_short + '.pkl', 'wb') as f:
        pickle.dump(taxa_dict, f)
# Out:
# 206684
# 206709
# 219676
# 206617
# 206701
# 215075
# 206673
# 206770
# 215004
# 206538
# 224324
# 206669
# 215085
# 206618
# 206683
# 206713
# 215067
# 206605
# 219693
# 224323
# 206762
# 215003
# 206604
# 206712
# 206660
# 206675
# 219692
# 206536
# 215084
# 206668
# 206682
# 206547
# 206619
# 219670
# 206548
# 215061
# 215074
# 206700
# 206616
# 206603
# 215010
# 224325
# 224330
# 206672
# 206667
# 206708
# 206670
# 224844
# 224327
# 206766
# 215007
# 206614
# 219668
# 206702
# 215076
# 222170
# 206609
# 219675
# 206678
# 206761
# 206677
# 206710
# 206718
# 206695
# 206769
# 215008
# 206534
# 224328
# 206681
# 206719
# 215009
# 206768
# 206676
# 219691
# 206704
# 206608
# 222171
# 215080
# 224326
# 206767
# 224845
# 206671
# 215077
# 215062
# 206703
# 206615
# 219669
# 206562
# 206629
# 219655
# 206658
# 206645
# 206746
# 206753
# 206621
# 215056
# 219652
# 206570
# 206738
# 206754
# 206741
# 206657
# 206730
# 206725
# 206626
# 206656
# 206643
# 206740
# 206755
# 206627
# 215050
# 206724
# 206731
# 206571
# 206564
# 215058
# 206739
# 219646
# 219653
# 219637
# 206752
# 206747
# 219638
# 206644
# 215057
# 206723
# 206620
# 206635
# 206628
# 219654
# 206563
# 206659
# 206622
# 206569
# 206734
# 206721
# 215055
# 206646
# 206750
# 206758
# 206561
# 206729
# 215048
# 219656
# 219643
# 206726
# 206733
# 206630
# 206625
# 219659
# 206742
# 206757
# 215023
# 214995
# 219644
# 219651
# 219634
# 206648
# 206572
# 219645
# 214994
# 206624
# 219658
# 206732
# 206727
# 206655
# 206756
# 206743
# 219633
# 219657
# 215049
# 206728
# 206720
# 206636
# 206623
# 206751
# 206647

# %%
d = None
filename = "206564"
with open('results/ibd/ibd_dicts/' + filename + '.pkl', 'rb') as f:
    d = pickle.load(f)

d
# Out:
# {'sample': {},
#  'domain': {'Bacteria': 4530, 'Archaea': 9},
#  'phylum': {'Proteobacteria': 758,
#   'Firmicutes': 2450,
#   'Bacteroidetes': 1295,
#   'Fusobacteria': 13,
#   'Woesearchaeota': 3,
#   'Euryarchaeota': 6,
#   'Actinobacteria': 7,
#   'Cyanobacteria/Chloroplast': 3,
#   'Acidobacteria': 4},
#  'class': {'Betaproteobacteria': 265,
#   'Clostridia': 2399,
#   'Bacteroidia': 1294,
#   'Gammaproteobacteria': 151,
#   'Deltaproteobacteria': 292,
#   'Alphaproteobacteria': 50,
#   'Erysipelotrichia': 29,
#   'Fusobacteriia': 13,
#   'AR20': 3,
#   'Negativicutes': 20,
#   'Methanopyri': 6,
#   'Coriobacteriia': 7,
#   'Cyanobacteria': 3,
#   'Bacilli': 2,
#   'Thermoanaerobaculia': 4,
#   'Chitinophagia': 1},
#  'order': {'Burkholderiales': 265,
#   'Clostridiales': 2399,
#   'Bacteroidales': 1294,
#   'Enterobacterales': 149,
#   'Desulfovibrionales': 292,
#   'Caulobacterales': 15,
#   'Erysipelotrichales': 29,
#   'Fusobacteriales': 13,
#   'AR20': 3,
#   'Sphingomonadales': 32,
#   'Veillonellales': 20,
#   'Methanopyrales': 6,
#   'Coriobacteriales': 7,
#   'I': 3,
#   'Bacillales': 2,
#   'Thermoanaerobaculales': 4,
#   'Kiloniellales': 1,
#   'Pseudomonadales': 2,
#   'Rhizobiales': 1,
#   'Chitinophagales': 1,
#   'Rhodobacterales': 1},
#  'family': {'Sutterellaceae': 194,
#   'XIII': 36,
#   'Lachnospiraceae': 843,
#   'Ruminococcaceae': 1520,
#   'Bacteroidaceae': 1080,
#   'Comamonadaceae': 43,
#   'Enterobacteriaceae': 148,
#   'Desulfovibrionaceae': 292,
#   'Barnesiellaceae': 85,
#   'Caulobacteraceae': 15,
#   'Erysipelatoclostridiaceae': 29,
#   'Leptotrichiaceae': 13,
#   'Rikenellaceae': 69,
#   'Muribaculaceae': 9,
#   'AR20': 3,
#   'Sphingomonadaceae': 32,
#   'Porphyromonadaceae': 41,
#   'Veillonellaceae': 20,
#   'Prevotellaceae': 1,
#   'Methanopyraceae': 6,
#   'Coriobacteriaceae': 7,
#   'Burkholderiaceae': 28,
#   'I': 3,
#   'Staphylococcaceae': 2,
#   'Odoribacteraceae': 9,
#   'Thermoanaerobaculaceae': 4,
#   'Kiloniellaceae': 1,
#   'Pseudomonadaceae': 2,
#   'Bradyrhizobiaceae': 1,
#   'Chitinophagaceae': 1,
#   'Rhodobacteraceae': 1,
#   'Morganellaceae': 1},
#  'genus': {'Sutterella': 194,
#   'Ihubacter': 36,
#   'Ruminococcus2': 135,
#   'Caproiciproducens': 81,
#   'Bacteroides': 349,
#   'Roseburia': 78,
#   'Phocaeicola': 731,
#   'Tepidimonas': 43,
#   'XlVa': 40,
#   'Escherichia/Shigella': 140,
#   'Faecalibacterium': 1282,
#   'Enterocloster': 87,
#   'Desulfovibrio': 272,
#   'Cuneatibacter': 27,
#   'Coprobacter': 77,
#   'Hungatella': 53,
#   'Fusicatenibacter': 79,
#   'Barnesiella': 8,
#   'Butyrivibrio': 43,
#   'Brevundimonas': 15,
#   'Merdimonas': 104,
#   'Erysipelatoclostridium': 29,
#   'Lachnospira': 9,
#   'Mordavella': 21,
#   'Dorea': 21,
#   'Leptotrichia': 13,
#   'Alistipes': 69,
#   'Muribaculum': 9,
#   'Anaerobutyricum': 38,
#   'Agathobacter': 6,
#   'AR20': 3,
#   'Sphingomonas': 30,
#   'Gemmiger': 67,
#   'Parabacteroides': 41,
#   'Veillonella': 19,
#   'Prevotella': 1,
#   'Kineothrix': 20,
#   'Faecalimonas': 36,
#   'Flintibacter': 71,
#   'Methanopyrus': 6,
#   'Citrobacter': 7,
#   'Blautia': 27,
#   'Herbinix': 1,
#   'Senegalimassilia': 7,
#   'Ralstonia': 28,
#   'Calochaete': 3,
#   'Bilophila': 20,
#   'Anaerostipes': 7,
#   'Staphylococcus': 2,
#   'Butyricimonas': 8,
#   'Dysosmobacter': 18,
#   'Thermoanaerobaculum': 4,
#   'Aestuariispira': 1,
#   'Pseudomonas': 2,
#   'Lachnospiracea_incertae_sedis': 1,
#   'Oribacterium': 1,
#   'Stomatobaculum': 1,
#   'Odoribacter': 1,
#   'Mediterraneibacter': 1,
#   'Bradyrhizobium': 1,
#   'Hydrotalea': 1,
#   'Planktotalea': 1,
#   'Coprococcus': 7,
#   'Rosenbergiella': 1,
#   'Sphingosinithalassobacter': 2,
#   'Proteus': 1,
#   'Dialister': 1,
#   'Neglecta': 1}}
